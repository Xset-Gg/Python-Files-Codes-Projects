# %%
#print("abubkar")
# Out:
# abubkar

# %%
#what is bainary
# binary is 0 1
# and pyhthon have a lot of tranlater but that man tranlater interpreter and compiler interpreter translate line by line code but compiler transalte all code whae

# %%
# Whenever i run the code but i dont execute this code i use comment commment sign is this #

# %%
# A variable is a named contatainer that stores data.multiplile data store varaible sign is this =

# %%
# this is runtime error
#a = "abu"
#print(a + 5) # string aur number add nahi ho sakta
# Typeerror: can only concatenate str (not "int") to str

# %%
#print("hello")  # bracket band nahi kiya
# systaxerror: unecpected edf

# %%
a = input("enter your class :")
b = input ("enter your school:")
print (f" your class is {a}")
print(f"your schoo is {b}")
# Out:
# enter your name : abubkar
# enter your age: 11
#  your name is abubkar
# your age is 11

# %%
print(5 +3)
# Out:
# 8

# %%
print(4- 2)
# Out:
# 2

# %%
# Type casting is use for one data type to convert another data type 

a =5
b = 2.4
c = a+b
print(type(a))
# Out:
# <class 'int'>

# %%
a = ["azan" , "abu" , "fozan" ,"apple"] 
a[1]= "abubkar"
print(a)
# Out:
# ['azan', 'abubkar', 'fozan', 'apple']

# %%
# this is azan
