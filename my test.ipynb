# %%
food = "pizza"
price = 10.99

num_of_food = int(input(f"How many {food}s? : "))
total = num_of_food * price

print(f"Your total is ${total}")
# Out:
# How many pizzas? :  6
# Your total is $11.94

# %%
name = "abubkar"
age = 12
gpa = 3.1
is_student = True

name = bool(name)
print(name)
# Out:
# True

# %%
name = input("What is your name")
age = input ("How old are you")

age = int(age)
age = age + 1

print(f'Hello{name}')
print("HAPPY BIRTHDAY")
print(f"you are {age} years old")
# Out:
# What is your name  ABUBKAR
# How old are you  12
# Hello ABUBKAR
# HAPPY BIRTHDAY
# you are 13 years old

# %%
item = input("What item would you like to buy? ")
price = float(input("What is the price? "))
quantity = int(input("How many would you like? "))

total = price * quantity

print(f"You bought {quantity} {item}(s).")
print(f"Your total is ${total:.2f}")
# Out:
# What item would you like to buy?  pizza
# What is the price?  10.99
# How many would you like?  11
# You bought 11 pizza(s).
# Your total is $120.89

# %%
import math

radius = float(input("Enter the radius of a circle: "))
circumference = 2 * math.pi * radius

print(f"The circumference is: {round(circumference, 2)} cm")
# Out:
# Enter the radius of a circle:  6
# The circumference is: 37.7 cm

# %%
import math

radius = float(input("Enter the radius of a circle: "))
area = math.pi * pow (radius,2)
print(f' the area of the circle is {area,2} mc2')
# Out:
# Enter the radius of a circle:  4
#  the area of the circle is (50.26548245743669, 2) mc2

# %%
import math

a = float(input("Enter side a: "))
b = float(input("Enter side b: "))

c = math.sqrt(pow(a, 2) + pow(b, 2))

print(f"The length of side c is {c:.2f}")
# Out:
# Enter side a:  5
# Enter side b:  6
# The length of side c is 7.81

# %%
operator = input("Enter an operator (+ - * /): ")

num1 = float(input("Enter the 1st number: "))
num2 = float(input("Enter the 2nd number: "))

if operator == "+":
    print(num1 + num2)
elif operator == "-":
    print(num1 - num2)
elif operator == "*":
    print(num1 * num2)
elif operator == "/":
    if num2 != 0:
        print(num1 / num2)
    else:
        print("Error: Cannot divide by zero.")
else:
    print("Invalid operator!")
# Out:
# Enter an operator (+ - * /):  -
# Enter the 1st number:  5
# Enter the 2nd number:  6
# -1.0

# %%
weight = float(input("Enter your weight"))
unit = input("kilogram or pounds (K or L)")
if unit == "K":
    weight =weight * 2.205
    unit = "Lbs"
elif unit == "L":
    weight = weight / 2.205
    unit = "Kgs"
else:
    print (f"{unit} was not valid")
print(f"your weight is {weight} {unit}")
# Out:
# Enter your weight 150
# kilogram or pounds (K or L) l
# l was not valid
# your weight is 150.0 l

# %%
weight = float(input("Enter your weight: "))
unit = input("Kilograms or Pounds? (K or L): ").upper()

if unit == "K":
    weight = weight * 2.205
    print(f"Your weight is {weight:.2f} Lbs")

elif unit == "L":
    weight = weight / 2.205
    print(f"Your weight is {weight:.2f} Kgs")

else:
    print(f"'{unit}' is not a valid unit. Please enter K or L.")
# Out:
# Enter your weight:  150
# Kilograms or Pounds? (K or L):  k
# Your weight is 330.75 Lbs

# %%
unit = input("Is this temperature in Celsius or Fahrenheit? (C/F): ").upper()
temp = float(input("Enter the temperature: "))

if unit == "C":
    temp = (temp * 9 / 5) + 32
    print(f"The temperature is {temp:.1f}°F")

elif unit == "F":
    temp = (temp - 32) * 5 / 9
    print(f"The temperature is {temp:.1f}°C")

else:
    print("Invalid unit. Please enter C or F.")
# Out:
# Is this temperature in Celsius or Fahrenheit? (C/F):  c
# Enter the temperature:  -1
# The temperature is 30.2°F

# %%
temp = float(input("🌡️ Enter the temperature: "))

sunny = input("☀️ Is it sunny? (yes/no): ").lower()

is_sunny = sunny == "yes"

if temp > 28 and is_sunny:
    print("🔥😎 It is hot outside! Don't forget your sunglasses. 🕶️")

elif temp > 28 and not is_sunny:
    print("🥵☁️ It is hot, but it's not sunny.")

elif temp <= 28 and is_sunny:
    print("😊🌤️ It is warm and sunny. Have a great day!")

else:
    print("🥶☁️ It is cool and not sunny. You may need a jacket. 🧥")
# Out:
# 🌡️ Enter the temperature:  -2
# ☀️ Is it sunny? (yes/no):  no
# 🥶☁️ It is cool and not sunny. You may need a jacket. 🧥

# %%
credit_number = input("💳 Enter your credit card number: ")

last_digits = credit_number[-4:]

print("\n🔒 Your card number is protected!")
print(f"💳 Card Number: XXXX-XXXX-XXXX-{last_digits}")
print("✅ Only the last 4 digits are visible for security.")
# Out:
# 💳 Enter your credit card number:  20000
# 🔒 Your card number is protected!
# 💳 Card Number: XXXX-XXXX-XXXX-0000
# ✅ Only the last 4 digits are visible for security.

# %%
price1 = 3.14159
price2 = -939.63
price3 = 12.34

print(f"Price 1: ${price1:.2f}")
print(f"Price 2: ${price2:.2f}")
print(f"Price 3: ${price3:.2f}")
# Out:
# Price 1: $3.14
# Price 2: $-939.63
# Price 3: $12.34

# %%
import random

options = ("rock", "paper", "scissors")

player = None
computer = random.choice(options)

player = input("Enter a choice (rock, paper, scissors): ").lower()

print(f"Player: {player}")
print(f"Computer: {computer}")
# Out:
# Enter a choice (rock, paper, scissors):  rock
# Player: rock
# Computer: paper

# %%
foods = []
prices = []
total = 0
while True:
    food = input("🍔 Enter a food to buy (q to quit): ")
    if food.lower() == "q":
        break
        price = float(input(f"💲 Enter the price of {food}: "))
        foods.append(food)
        prices.append(price)
print("\n🛒------ YOUR SHOPPING CART ------")

for food in foods:
    print(food, end=" ")

print()
for price in prices:
    total += price
print(f"\n💰 Your total is: ${total:.2f}")
# Out:
# 🍔 Enter a food to buy (q to quit):  :   "pizza"
# 🍔 Enter a food to buy (q to quit):  10.99
# 🍔 Enter a food to buy (q to quit):  burger
# 🍔 Enter a food to buy (q to quit):  10.5
# 🍔 Enter a food to buy (q to quit):  coffe
# 🍔 Enter a food to buy (q to quit):  10
# 🍔 Enter a food to buy (q to quit):  q
# 🛒------ YOUR SHOPPING CART ------
#
#
# 💰 Your total is: $0.00

# %%
import random
options = ("rock", "paper", "scissors")
player = input("🪨📄✂️ Enter your choice (rock, paper, scissors): ").lower()
computer = random.choice(options)
print(f"\n👤 You chose: {player}")
print(f"🤖 Computer chose: {computer}")
if player not in options:
    print("❌ Invalid choice!")
elif player == computer:
    print("🤝 It's a tie!")
elif (player == "rock" and computer == "scissors") or \
     (player == "paper" and computer == "rock") or \
     (player == "scissors" and computer == "paper"):
    print("🎉 You win!")

else:
    print("😢 Computer wins!")
# Out:
# 🪨📄✂️ Enter your choice (rock, paper, scissors):  rock
# 👤 You chose: rock
# 🤖 Computer chose: paper
# 😢 Computer wins!

# %%
def net_price(list_price, discount=0, tax=0.05):
    return list_price * (1 - discount) * (1 + tax)

price = net_price(100)
print(f"Net Price: ${price:.2f}")
# Out:
# Net Price: $105.00

# %%
def net_price(list_price, discount=0.20, tax=0.05):
    return list_price * (1 - discount) * (1 + tax)

price = net_price(100)
print(f"Net Price: ${price:.2f}")
# Out:
# Net Price: $84.00

# %%
numbers =(1,2,3,4,5,6)
for number in numbers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
numbers =("abubkar","azan","fozan","ali")
for number in numbers:
    print(number)
# Out:
# abubkar
# azan
# fozan
# ali

# %%
numbers = {
    "A": 1,
    "B": 2,
    "C": 3
}

for number in numbers:
    print(number)
# Out:
# A
# B
# C

# %%
numbers = {
    "A": 1,
    "B": 2,
    "C": 3
}

for kay in numbers:
    print(kay)
# Out:
# A
# B
# C

# %%
a = "ABUBKAR"
abu=input("Guess a letter in the secret a")
if abu in a:
    print(f"there is a {abu}")
else:
    print(f"{abu}was not found")
# Out:
# Guess a letter in the secret a A
# there is a A

# %%
abu = {"abubkar","azan","fozan","ali"}
b = input("Enter the name of a abu")
if b in abu:
    print(f"{b} is a ali")
else:
    print(f"{b} was not found")
# Out:
# Enter the name of a abu abubkar
# abubkaris a ali

# %%
abu = {
    "sandy": "A",
    "squidward": "B",
    "spongebob": "C"
}

print(abu)
# Out:
# {'sandy': 'a', 'squidward': 'b', 'spongebob': 'c'}

# %%
grades = {
    "sandy": "A",
    "squidward": "B",
    "spongebob": "C"
}

student = input("Enter the name of a student: ").lower()

if student in grades:
    print(f"{student}'s grade is {grades[student]}")
else:
    print(f"{student} was not found.")
# Out:
# Enter the name of a student:  sandy
# sandy's grade is A

# %%
email = input("Enter your email: ")

if "@" in email and "." in email:
    print("Valid email address")
else:
    print("Invalid email address")
# Out:
# Enter your email:    BroCode@gmail.com
# Valid email address

# %%
abu = [1, -2, 3, -4, 5, -6]

ali = [num for num in abu if num >= 0]
king = [num for num in abu if num > 0]

print(ali)
print(king)
# Out:
# [1, 3, 5]
# [1, 3, 5]

# %%
def func1():
    x = 1
    print(x)

def func2():
    x = 2
    print(x)
func1()
func2()
# Out:
# 1
# 2

# %%
balance = 0

def show_balance():
    print(f"\nYour balance is ${balance:.2f}")

def deposit():
    amount = float(input("Enter an amount to deposit: $"))

    if amount < 0:
        print("That's not a valid amount!")
        return 0
    else:
        return amount

def withdraw():
    amount = float(input("Enter amount to withdraw: $"))

    if amount > balance:
        print("Insufficient funds!")
        return 0
    elif amount < 0:
        print("Amount must be greater than 0!")
        return 0
    else:
        return amount

def main():
    global balance

    is_running = True

    while is_running:
        print("\n********** Banking Program **********")
        print("1. Show Balance")
        print("2. Deposit")
        print("3. Withdraw")
        print("4. Exit")

        choice = input("Enter your choice (1-4): ")

        if choice == "1":
            show_balance()

        elif choice == "2":
            balance += deposit()

        elif choice == "3":
            balance -= withdraw()

        elif choice == "4":
            is_running = False
            print("Thank you! Have a nice day.")

        else:
            print("Invalid choice. Please enter 1-4.")

main()
# Out:
# ********** Banking Program **********
# 1. Show Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice (1-4):  3
# Enter amount to withdraw: $ 300
# Insufficient funds!
#
# ********** Banking Program **********
# 1. Show Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice (1-4):  4
# Thank you! Have a nice day.

# %%
class Car:
    def __init__(self, brand, model, year, color, for_sale):
        self.brand = brand
        self.model = model
        self.year = year
        self.color = color
        self.for_sale = for_sale
# Out:
# Corvette
# 2025
# Blue
# True

# %%
class Abublar:
    def __init__(self, name):
        self.name = name
        self.is_alive = True

person1 = Abublar("Azan")

print(person1.name)
print(person1.is_alive)
# Out:
# Azan
# True

# %%
class Abublar:
    def __init__(self, name):
        self.name = name
        self.is_alive = True

    def eat(self):
        print(f"{self.name} is eating")

    def sleep(self):
        print(f"{self.name} is sleeping")


class Dog(Abublar):
    pass


class Cat(Abublar):
    pass


class Mouse(Abublar):
    pass


dog = Dog("Buddy")
mouse = Mouse("Jerry")

dog.eat()
mouse.sleep()
# Out:
# Buddy is eating
# Jerry is sleeping

# %%
class Prey:
    def flee(self):
        print("This animal is fleeing")


class Predator:
    def hunt(self):
        print("This animal is hunting")


class Rabbit(Prey):
    pass


class Hawk(Predator):
    pass


class Fish(Prey, Predator):
    pass


rabbit = Rabbit()
hawk = Hawk()
fish = Fish()

rabbit.flee()
hawk.hunt()
fish.flee()
# Out:
# This animal is fleeing
# This animal is hunting
# This animal is fleeing

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius


class Square:
    def __init__(self, side):
        self.side = side


class Triangle:
    def __init__(self, base, height):
        self.base = base
        self.height = height


circle = Circle(5)
square = Square(7)
triangle = Triangle(6, 8)

print(circle.radius)
print(square.side)
print(triangle.base)
print(triangle.height)
# Out:
# 5
# 7
# 6
# 8

# %%
class Shape:
    def __init__(self, color, is_filled):
        self.color = color
        self.is_filled = is_filled


class Circle(Shape):
    def __init__(self, color, is_filled, radius):
        super().__init__(color, is_filled)
        self.radius = radius


class Square(Shape):
    def __init__(self, color, is_filled, width):
        super().__init__(color, is_filled)
        self.width = width


class Triangle(Shape):
    def __init__(self, color, is_filled, width, height):
        super().__init__(color, is_filled)
        self.width = width
        self.height = height


circle = Circle("Red", True, 5)
square = Square("Blue", False, 10)
triangle = Triangle("Green", True, 8, 1)


print(circle.color)
print(circle.radius)

print(square.color)
print(square.width)

print(triangle.color)
print(triangle.height)
# Out:
# Red
# 5
# Blue
# 10
# Green
# 1

# %%
from abc import ABC, abstractmethod


class Shape(ABC):

   
    def area(self):
        pass


class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius


class Square(Shape):

    def __init__(self, side):
        self.side = side

    def area(self):
        return self.side * self.side


class Triangle(Shape):

    def __init__(self, base, height):
        self.base = base
        self.height = height

    def area(self):
        return 0.5 * self.base * self.height


circle = Circle(5)
square = Square(6)
triangle = Triangle(6, 4)


print(circle.area())
print(square.area())
print(triangle.area())
# Out:
# 78.5
# 36
# 12.0

# %%
class Animal:
    alive = True

class Dog(Animal):
    def speak(self):
        print("The dog says Woof")

class Cat(Animal):
    def speak(self):
        print("The cat says Meow")
animals = [Dog(),Cat()]
for animal in animals:
    animal.speak()
# Out:
# The dog says Woof
# The cat says Meow

# %%
class Animal:
    alive = True

class Dog(Animal):
    def speak(self):
        print("The dog says Woof")

class Car(Animal):
    def speak(self):
        print("The car says Beep")

class Cat(Animal):
    def speak(self):
        print("The cat says Meow")

animals = [Dog(), Cat(), Car()]

for animal in animals:
    animal.speak()
    print(animal.alive)
# Out:
# The dog says Woof
# True
# The cat says Meow
# True
# The car says Beep
# True

# %%
class Employee:
    def __init__(self, name, position):
        self.name = name
        self.position = position

    def get_info(self):
        return f"{self.name} = {self.position}"

    @staticmethod
    def is_valid_position(position):
        valid_positions = ["Manager", "Cashier", "Cook", "Janitor"]
        return position in valid_positions


employee1 = Employee("Ali", "Manager")

print(employee1.get_info())

print(Employee.is_valid_position("Cook"))
print(Employee.is_valid_position("Driver"))
# Out:
# Ali = Manager
# True
# False

# %%
class Student:
    count = 0

    def __init__(self, name, gpa):
        self.name = name
        self.gpa = gpa
        Student.count += 1

    def get_info(self):
        return f"{self.name} = {self.gpa}"

    @classmethod
    def get_count(cls):
        return f"Total students: {cls.count}"


Student1 = Student("Azan", 3.8)

print(Student.get_count())
# Out:
# Total students: 1

# %%
class Book:
    def __init__(self, title, author, num_pages):
        self.title = title
        self.author = author
        self.num_pages = num_pages

    def get_info(self):
        return f"{self.title} by {self.author} - {self.num_pages} pages"


book1 = Book("The Hobbit", "J.R.R. Tolkien", 310)
book2 = Book("Harry Potter", "J.K. Rowling", 500)
book3 = Book("Python Basics", "abu", 200)

print(book1.get_info())
print(book2.get_info())
print(book3.get_info())
# Out:
# The Hobbit by J.R.R. Tolkien - 310 pages
# Harry Potter by J.K. Rowling - 500 pages
# Python Basics by abu - 200 pages

# %%
class Abu:
    def __init__(self,width,height): 
        self.width=width
        self.height=height
abu = Abu(3,4)
print(abu.width)
print(abu.height)
# Out:
# 3
# 4

# %%
class Abu:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def show(self):
        print(f"Width: {self.width}")
        print(f"Height: {self.height}")

abu = Abu(3, 4)
abu.show()
# Out:
# Width: 3
# Height: 4

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def greet(self):
    print("Hello, my name is " + self.name)

p1 = Person("Emil", 25)
p1.greet()
# Out:
# Hello, my name is Emil

# %%
class Person:
  def __init__(myobject, name, age):
    myobject.name = name
    myobject.age = age

  def greet(abc):
    print("Hello, my name is " + abc.name)

p1 = Person("Abubkar", 12)
p1.greet()
# Out:
# Hello, my name is Abubkar

# %%
class Car:
  def __init__(self, brand, model, year):
    self.brand = brand
    self.model = model
    self.year = year

  def display_info(self):
    print(f"{self.year} {self.brand} {self.model}")

car1 = Car("Toyota", "Corolla", 2020)
car1.display_info()
# Out:
# 2020 Toyota Corolla

# %%
class Abu:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

    def perimeter(self):
        return 2 * (self.width + self.height)

    def is_square(self):
        return self.width == self.height

    def display(self):
        print("Width      :", self.width)
        print("Height     :", self.height)
        print("Area       :", self.area())
        print("Perimeter  :", self.perimeter())
        print("Is Square? :", self.is_square())


# Objects
abu1 = Abu(3, 4)
abu2 = Abu(5, 5)

abu1.display()
print("-" * 30)
abu2.display()
# Out:
# Width      : 3
# Height     : 4
# Area       : 12
# Perimeter  : 14
# Is Square? : False
# ------------------------------
# Width      : 5
# Height     : 5
# Area       : 25
# Perimeter  : 20
# Is Square? : True

# %%
class Fruit:
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def display(self):
        print(f"Fruit : {self.name}")
        print(f"Price : Rs. {self.price} per kg")
        print("-" * 25)


# Objects
mango = Fruit("Mango", 250)
banana = Fruit("Banana", 120)
cherry = Fruit("Cherry", 600)
guava = Fruit("Guava", 180)
grapes = Fruit("Grapes", 300)

# Display all fruits
mango.display()
banana.display()
cherry.display()
guava.display()
grapes.display()
# Out:
# Fruit : Mango
# Price : Rs. 250 per kg
# -------------------------
# Fruit : Banana
# Price : Rs. 120 per kg
# -------------------------
# Fruit : Cherry
# Price : Rs. 600 per kg
# -------------------------
# Fruit : Guava
# Price : Rs. 180 per kg
# -------------------------
# Fruit : Grapes
# Price : Rs. 300 per kg
# -------------------------

# %%
try:
    number = int(input("Enter a number: "))
    print(1 / number)
except ZeroDivisionError:
    print("You can't divide by zero, IDIOT!")
except ValueError:
    print("Please enter a valid integer number!")
except Exception as e:
    print(f"Something unexpected went wrong: {e}")
finally:
    print("Calculation finished. Have  a nice day!")  # Final cleanup/goodbye message
# Out:
# Enter a number:  4
# 0.25
# Calculation finished. Have  a nice day!

# %%
ali = open("abu.txt","a")
ali.write("this is fozan")
ali.close()
with open("abu.txt",) as f:
    print(f.read())
# Out:
# this is fozanthis is fozan

# %%
o =open("abu.txt","r")
print(o.read())
# Out:
# this is fozanthis is fozan

# %%
with open("abu.txt","r")as f:
    print(f.read())
# Out:
# this is fozanthis is fozan

# %%
with open("abu.txt","r")as f:
    print(f.read(2))
# Out:
# th

# %%
with open("abu.txt")as f:
    print(f.readline())
    f.close()
# Out:
# this is fozanthis is fozan

# %%
with open("abu.txt")as f:
    for a in f:
        print(a)
# Out:
# this is fozanthis is fozan

# %%
ali = open("abu.txt","a")
ali.write("this is fozan")
ali.close()
with open("abu.txt",)as f:
    print(f.read())
# Out:
# this is fozanthis is fozanthis is fozan

# %%
with open("abu.txt","w")as f:
    f.write("this is fozan")
    f.close
x=open("abu.txt",'r')
print(x.read())
# Out:
# this is fozan

# %%
import os
os.remove("ali.txt")

# %%
import datetime

abu=datetime.date(2026,1,2)
print("Abu's Date:",abu)

now=datetime.datetime.now()
formatted_time=now.strftime("%H:%M:%S-%d-%b-%Y")
print("Current Time:",formatted_time)

target_datetime=datetime.datetime(3030,1,2,12,30,1)
current_datetime=datetime.datetime.now()

if target_datetime<current_datetime:
    print("Target date has passed")
else:
    print("Target date has NOT passed")
# Out:
# Abu's Date: 2026-01-02
# Current Time: 21:51:09-23-Jul-2026
# Target date has NOT passed

# %%
import warnings
warnings.filterwarnings("ignore")

import pygame
import time

pygame.mixer.init()
pygame.mixer.music.load(r"C:\CarProject\alarm.mp3")

print("Playing sound...")

pygame.mixer.music.play()

time.sleep(20)

pygame.mixer.music.stop()

print("Finished")
# Out:
# Playing sound...
# Finished

# %%
import threading
import time

def walk_dog():
    time.sleep(8)
    print("You finish walking the dog")

def take_out_trash():
    time.sleep(2)
    print("You finish taking out the trash")

def clean_room():
    time.sleep(5)
    print("You finish cleaning the room")


# Create threads
task1 = threading.Thread(target=walk_dog)
task2 = threading.Thread(target=take_out_trash)
task3 = threading.Thread(target=clean_room)

# Start threads
task1.start()
task2.start()
task3.start()

# Wait for all threads to finish
task1.join()
task2.join()
task3.join()

print("All tasks completed!")
# Out:
# You finish taking out the trash
# You finish cleaning the room
# You finish walking the dog
# All tasks completed!

# %%
import requests

def get_pokemon_info(name):
    url = f"https://pokeapi.co/api/v2/pokemon/{name}"

    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()

        print("Name:", data["name"])
        print("ID:", data["id"])
        print("Height:", data["height"])
        print("Weight:", data["weight"])

        print("Abilities:")
        for ability in data["abilities"]:
            print("-", ability["ability"]["name"])

    else:
        print("Pokemon not found")


pokemon_name = "pikachu"
get_pokemon_info(pokemon_name)
# Out:
# Name: pikachu
# ID: 25
# Height: 4
# Weight: 60
# Abilities:
# - static
# - lightning-rod

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget

app = QApplication(sys.argv)

window = QWidget()
window.setWindowTitle("My First PyQt5 App")
window.resize(400, 300)
window.show()

sys.exit(app.exec())

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QLabel, QPushButton

app = QApplication(sys.argv)

window = QWidget()
window.setWindowTitle("My First PyQt5 App")
window.setGeometry(200, 200, 500, 300)

label = QLabel("Welcome to PyQt5!", window)
label.move(170, 50)

button = QPushButton("Click Me", window)
button.move(190, 120)
button.resize(100, 40)

def button_clicked():
    label.setText("Button Clicked!")
    label.adjustSize()

button.clicked.connect(button_clicked)

window.show()

sys.exit(app.exec())

# %%
import sys
from PyQt5.QtWidgets import QApplication, QMainWindow, QLabel

class MainWindow(QMainWindow):
    def __init__(self):
        super().__init__()
        self.initUI()

    def initUI(self):
        self.setWindowTitle("My Main Window")
        self.setGeometry(200, 200, 500, 300)

        label = QLabel("Welcome to PyQt5!", self)
        label.move(170, 120)

app = QApplication(sys.argv)

window = MainWindow()
window.show()

sys.exit(app.exec())
