# %%
a = 80
x = "ABUBKAR"  if a > 40 else "khan"
print(x)
# Out:
# ABUBKAR

# %%
a = 3 
x = "sat" if a ==5 else "friday" if a == 4 else "thusday" if a == 3 else "monady"
print(x)
# Out:
# thusday

# %%
#6/8/2026

# %%
a = ["abubkar " ,"khan"]
b = ["abubkar ", "khan"]
z = a
print( a is z)
print(b is z)
print( a== b)
# Out:
# True
# False
# True

# %%
a = [11,22,33,44,55]
b = [11,22,33,44,55]
c = b
print(c is b)
print(a ==b)
# Out:
# True
# True

# %%
a = ["abubkar" ,"azan","fozan"]
print("azan"in a)
# Out:
# True

# %%
a = ["abubkar" ,"azan","fozan"]
print("khan"in a)

# %%
a = ["abubkar" ,"azan","fozan"]
print("khan " not in a)
# Out:
# True

# %%
a = ["abubkar" ,"azan","fozan"]
print("azan"not in a)
# Out:
# False

# %%
a = "abubkar khan"
print("j" in a)
print("khan" in a)
print("abab" not in a)
# Out:
# False
# True
# True

# %%
#6/10/2026

# %%
a = [1,2,3,4,5]
if len(a) > 3:
    print("yes its greater")
# Out:
# yes its greater

# %%
a = int(input("enter a number"))
x = "sat" if a ==5 else "friday" if a == 4 else "thusday" if a == 3 else "monady"
print(x)
# Out:
# enter a number 1
# monady

# %%
a = "abubkar "
b = "abubkar"
z=b
print(z is b)
print(a==b)
# Out:
# True
# False

# %%
#7/11/2036

# %%
a = ["abubkar","azan", "fozan"]
print(a[1])
# Out:
# azan

# %%
a = ["abubkar","azan", "fozan"]
a[2]="shayan"
print(a)
# Out:
# ['abubkar', 'azan', 'shayan']

# %%
a = ["abubkar","azan", "fozan"]
a.remove("azan")
print(a)
# Out:
# ['abubkar', 'fozan']

# %%
a = ["abubkar","azan", "fozan"]
x =["khan","king","shayan"]
y=a.copy()

print(y)
print(a+x)
# Out:
# ['abubkar', 'azan', 'fozan']
# ['abubkar', 'azan', 'fozan', 'khan', 'king', 'shayan']

# %%
x =("abubkar","azan","fozan")
y=list(x)
y[1]= "king"
x = tuple(y)
print(x)
# Out:
# ('abubkar', 'king', 'fozan')

# %%
a = {"apple", "banana", "cherry", True, 1, 2}

print(a)
# Out:
# {True, 2, 'cherry', 'apple', 'banana'}

# %%
abu = {"apple", "banana", "cherry"}
ali = {"pineapple", "mango", "papaya"}

abu.update(ali)

print(abu)
# Out:
# {'cherry', 'mango', 'apple', 'papaya', 'pineapple', 'banana'}

# %%
y = {"apple", "banana", "cherry"}

x = y.pop()

print(x)

print(y)
# Out:
# cherry
# {'apple', 'banana'}

# %%
abu = {"apple", "banana", "cherry"}

abu.clear()

print(abu)
# Out:
# set()

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
del thisdict["model"]
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
#a= 10
#while a <20:
    #print("my name is abubkar",a)
    #a= a+1

#i = 1
#while i < 6:
  #print(i)
  #if i == 3:
    #break continue
  #i += 1
#i = 1
#while i < 6:
  #print(i)
 # i += 1
#else:
  #print("i is no longer less than 6")

#a =[11,22,33,44,55,66]
#print(a)
#for i in a:
    #print(a)
#a= ["abu","azan","fozan" , "khan" , "king"]
#for i in a:
    #if a == "abu":
        #continue
    #print(i)
#for i in "abu":
   # print(i)
#a = 33
#b = 33
#if b > a:
  #print("b is greater than a")
#elif a == b:
  #print("a and b are equal")

# %%
a = int(input("enter a number"))
x = "sat" if a ==5 else "friday" if a == 4 else "thusday" if a == 3 else "monady"
print(x)
# Out:
# enter a number 3
# thusday

# %%
x =("abubkar","azan","fozan")
y=list(x)
y[1]= "king"
x = tuple(y)
print(x)
# Out:
# ('abubkar', 'king', 'fozan')

# %%
a = "abubkar khan"
print("j" in a)
print("khan" in a)
print("abab" not in a)
# Out:
# False
# True
# True

# %%
a = ["abubkar","azan","fozan"]
a.clear()
print(a)
# Out:
# []

# %%
a = ["abubkar","azan","fozan"]
a.remove("azan")
print(a)
# Out:
# ['abubkar', 'fozan']

# %%
a = ["abubkar","azan","fozan"]
del a[0:2]
print (a)
# Out:
# ['fozan']

# %%
u=["azan","abubkar","fozan"]
a=["khan","king"]
u.extend(a)
print(u)
# Out:
# ['azan', 'abubkar', 'fozan', 'khan', 'king']

# %%
a={"name" : "abubkar",
 "age" : 11
}
a.keys()
print(len(a))
# Out:
# 2

# %%
a = int(input("inter your nabear"))
b = int(input("this is cal nambear"))
c = int(input("my name is "))
d = int(input("my  my name is abubkar"))
if a< b and a<c and a<b:
    print("this is  nabera",a)
elif b < a and  b < c and c > d :
    print("abubkar " , b)
elif c < a and  c < b and c < d:
    print("third number is greater")
else: 
    print("forth number is small",d)
# Out:
# inter your nabear 1
# this is cal nambear 2
# my name is  3
# my  my name is abubkar 4
# this is  nabera 1

# %%
a = int(input("inter your nabear"))
b = int(input("this is cal nambear"))
for i in range(a,b,1):
    if 1 % 2 ==0:
        print(f'inter your nabear{i}is even')
else:
    print(f"this is cal nambea{i}is add")
# Out:
# inter your nabear 0
# this is cal nambear 5
# this is cal nambea3is add

# %%
a = int(input("inter your nabear"))
b = int(input("this is cal nambear"))
for i in range(a,b):
    if i % 2 ==0:
        print ("this is even ", i)
    else:
        print ("this is odd", i)
# Out:
# inter your nabear 1
# this is cal nambear 2
# this is odd 1

# %%
ali = open("abu.txt","a")
ali.write("this is fozan")
ali.close()
with open("abu.txt",) as f:
    print(f.read())
# Out:
# this is fozan

# %%
o =open("abu.txt","r")
print(o.read())
# Out:
# this is fozan

# %%
with open("abu.txt","r")as f:
    print(f.read())
# Out:
# this is fozan

# %%
with open("abu.txt","r")as f:
    print(f.read(2))
# Out:
# th

# %%
with open("abu.txt")as f:
    print(f.readline())
    f.close()
# Out:
# this is fozan

# %%
with open("abu.txt")as f:
    for a in f:
        print(a)
# Out:
# this is fozan

# %%
ali = open("abu.txt","a")
ali.write("this is fozan")
ali.close()
with open("abu.txt",)as f:
    print(f.read())
# Out:
# this is fozanthis is fozan

# %%
with open("abu.txt","w")as f:
    f.write("this is fozan")
    f.close
x=open("abu.txt",'r')
print(x.read())
# Out:
# this is fozan

# %%
import os
os.remove("ali.txt")

# %%
import re
ali = "my name is abubkar"
x=re.findall("my",ali)
print(x)
# Out:
# ['my']

# %%
import re
ali = "my name is abubkar my age 11"
x=re.findall("\s",ali)
print(len(x))
# Out:
# 6

# %%
import re
ali = "my name is abubkar my age 11"
x=re.search("name",ali)
print(x)
# Out:
# <re.Match object; span=(3, 7), match='name'>

# %%
import re
ali = "my name is abubkar my age 11"
x=re.split("\s",ali)
print(x)
# Out:
# ['my', 'name', 'is', 'abubkar', 'my', 'age', '11']

# %%
import re
ali = "my name is abubkar my age 11"
x=re.sub("is","in",ali)
print(x)
# Out:
# my name in abubkar my age 11
