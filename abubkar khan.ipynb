# %%
a = ("abubkar", "azan", "fozan")
print(type(a))
print(a[1])
# Out:
# <class 'tuple'>
# azan

# %%
a = ("abubkar", "azan", "fozan")
x = list(a)
y=x.insert(1,"khan")
abu=tuple (x)
print(abu)
# Out:
# ('abubkar', 'khan', 'azan', 'fozan')

# %%
a = ("abubkar", "azan", "fozan")
y = ("king",)
a+=y

print(a)
# Out:
# ('abubkar', 'azan', 'fozan', 'king')

# %%
a = ("abubkar", "azan", "fozan")
y = ("king",)
print(a+y)
# Out:
# ('abubkar', 'azan', 'fozan', 'king')

# %%
a = ("abubkar", "shayan", "musa")
(khan,hmmm,king)=a
print(khan)
print(king)
print(hmmm)
# Out:
# abubkar
# musa
# shayan

# %%
a = ["a","b","c"]
[x,v,z,]=a
print(x),(v),(z)
# Out:
# a
# (None, 'b', 'c')

# %%
a = ("abubkar", "shayan", "musa")
for  i in range(len(a)):
    print(a[i])
# Out:
# abubkar
# shayan
# musa

# %%
a = ("abubkar", "shayan", "musa")
x = a *2
print(x)
# Out:
# ('abubkar', 'shayan', 'musa', 'abubkar', 'shayan', 'musa')

# %%
a = ("abubkar", "shayan","shayan", "musa")
print(a.count("shayan"))
# Out:
# 2

# %%
a = ("abubka"musa"r", "shayan", )
print(a.index("musa"))
# Out:
# 2

# %%
ali= {"abubkar", "shayan", "musa"}
ali . add("khan")
print(ali)
# Out:
# {'shayan', 'abubkar', 'musa', 'khan'}

# %%
a = {"age" :"11","my name is" : "abubkar"}
print(a)
# Out:
# {'age': '11', 'my name is': 'abubkar'}

# %%
a = {"age" :"11","my name is" : "abubkar"}
print(a.values())
print(len(a))
# Out:
# dict_values(['11', 'abubkar'])
# 2

# %%
a = 34
b = 38
if a < b:
    print("ko")
else:
    print("no")
# Out:
# ko

# %%
#############
def ali():
    print("this is functino boby")

ali()
# Out:
# this is functino boby

# %%
def ali(sname,fname,clas): #this is perameter
    print(f"my name is {sname} and my fatherer name is  {fname} and clas is {clas}")
ali("abubkar","luqman","6") # thi is arguments
# Out:
# my name is abubkar and my fatherer name is  luqman and clas is 6

# %%
a="pakistan"
def ali():
    a="pakistan"
    print("abubkar is going to swiming pool")
ali()
print(a)
# Out:
# abubkar is going to swiming pool
# pakistan

# %%
def khan(name, cls):
    print(f" my name is {name} and class is {cls}")
khan("azan", "34")
# Out:
#  my name is azan and class is 34

# %%
o =open("abu.txt")
print(o.read())
# Out:
# my name abubkar my name is azan

# %%
with open("abu.txt")as f:
    print(f.read())
# Out:
# my name abubkar my name is azan

# %%
with open("abu.txt")as f:
    print(f.read(2))
# Out:
# my

# %%
with open("abu.txt")as f:
    print(f.readline())
    f.close()
# Out:
# my name abubkar my name is azan

# %%
with open("abu.txt")as f:
    print(f.readlines())
    f.close()
# Out:
# ['my name abubkar my name is azan']

# %%
with open("abu.txt")as f:
    for a in f:
        print(a)
####3
# Out:
# my name abubkar my name is azan

# %%
ali = open("abu.txt","a")
ali.write("this is fozan")
ali.close()
with open("abu.txt",)as f:
    print(f.read())
# Out:
# this is fozan

# %%
with open("abu.txt","w")as f:
    f.write("this is fozan")
    f.close
x=open("abu.txt",'r')
print(x.read())
# Out:
# this is fozan

# %%
import os
os.remove("ali.txt")

# %%
import re
ali = "my name is abubkar"
x=re.findall("my",ali)
print(x)
# Out:
# ['my']

# %%
import re
ali = "my name is abubkar my age 11"
x=re.findall("\s",ali)
print(len(x))
# Out:
# 6

# %%
import re
ali = "my name is abubkar my age 11"
x=re.search("name",ali)
print(x)
# Out:
# <re.Match object; span=(3, 7), match='name'>

# %%
import re
ali = "my name is abubkar my age 11"
x=re.split("\s",ali)
print(x)
# Out:
# ['my', 'name', 'is', 'abubkar', 'my', 'age', '11']

# %%
import re
ali = "my name is abubkar my age 11"
x=re.sub("is","in",ali)
print(x)
# Out:
# my name in abubkar my age 11

# %%
def ali():
    print("this is functino boby")

ali()
# Out:
# this is functino boby

# %%
def ali(sname,fname,clas): #this is perameter
    print(f"my name is {sname} and my fatherer name is  {fname} and clas is {clas}")
ali("abubkar","luqman","6") # thi is arguments
# Out:
# my name is abubkar and my fatherer name is  luqman and clas is 6

# %%
a="pakistan"
def ali():
    a="pakistan"
    print("abubkar is going to swiming pool")
ali()
print(a)
# Out:
# abubkar is going to swiming pool
# pakistan

# %%
def khan(name, cls):
    print(f" my name is {name} and class is {cls}")
khan("azan", "34")
# Out:
#  my name is azan and class is 34
