# %%
#5-19-2026

# %%
a =34
b =35.5
c =56j
d = "abu"
e = True
for i in [a,b,c,d,e]:
    print(type(i))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'bool'>

# %%
a =34
c = 35j
d = 23.4
e= "24"
print(type(e),e)
print(type(float(a)))
d=int(b)
print(type(d),d)
print(type(complex(b)))
# Out:
# <class 'str'> 24
# <class 'float'>
# <class 'int'> 35
# <class 'complex'>

# %%
a= "abubkar khan"
print(a)
# Out:
# abubkar khan

# %%
a = """abubkar khan
fozan khan"""
print(a[0:8])
# Out:
# abubkar

# %%
a = "abubkar khan "
for i in a:
    print(i)
    if i =='k':
        continue
        
        print("my name is ")
# Out:
# a
# b
# u
# b
# k
# a
# r
#
# k
# h
# a
# n

# %%
a = "abubkar khan"
print(len(a))
# Out:
# 12

# %%
a = "abubkar khan"
print("khan" in a)
# Out:
# True

# %%
a = "abubkar khan"
print("king" in a)
# Out:
# False

# %%
#5/20/2026

# %%
a = "abubkar khan"
print(a.upper())
b = "ABUBKAR KHAN"
print(b.lower())
# Out:
# ABUBKAR KHAN
# abubkar khan

# %%
a = "   abubkar khan     "
print(a.strip())
# Out:
# abubkar khan

# %%
a = "abubkar khan"
print(a.replace("abubkar" ,"azan"))
# Out:
# azan khan

# %%
a ="abubkar khan azan  khan fozan khan"
print(a.split(" "))
# Out:
# ['abubkar', 'khan', 'azan', '', 'khan', 'fozan', 'khan']

# %%
a = "abubkar khan"
b=a.split(" ")
print(len(b))
# Out:
# 2

# %%
a = "abubkar"
b = " khan"
c = a + b
print(c)
# Out:
# abubkar khan

# %%
age = 11
a= (f"my name is abubkar {age:.2f}")
print(a)
# Out:
# my name is abubkar 11.00

# %%
a = "my name is \"ABUBKAR\" and am learning python"
print(a)
# Out:
# my name is "ABUBKAR" and am learning python

# %%
a = "abubkar\r khan"
print(a)
# Out:
#  khanar

# %%
a = "abubkar  \b khan"
print(a)
# Out:
# abubkar  khan

# %%
a = "abubkar \n khan"
print(a)
# Out:
# abubkar
#  khan

# %%
a = "abubkar\t khan"
print(a)
# Out:
# abubkar	 khan

# %%
#5/21/2026

# %%
a ="abubkar khan"
print(a.capitalize())
# Out:
# Abubkar khan

# %%
a ="abubkar khan"
print(a.center(100))
# Out:
#                                             abubkar khan

# %%
a ="abubkar khan abubkar king"
print(a.count("abubkar"))
# Out:
# 2

# %%
a ="abubkar khan"
print(a.encode())
# Out:
# b'abubkar khan'

# %%
a ="my name is abubkar khan"
print(a.endswith("khan"))
# Out:
# True

# %%
a ="my name is abubkar\t khan"
b=a.expandtabs(4)
print(b)
# Out:
# my name is abubkar   khan

# %%
#5/22/2026

# %%
a ="my name is abubkar khan"
print(a.find("khan"))
# Out:
# 19

# %%
a ="my name is abubkar khan"
print(a.index("abubkar"))
# Out:
# 11

# %%
print(10 > 5)
# Out:
# True

# %%
print(10 < 5)
# Out:
# False

# %%
print(bool("khan"))
print(bool(45))
print(bool())
# Out:
# True
# True
# False

# %%
a = 45# addition
b =  34
print(a + b)
# Out:
# 79

# %%
a = 45#subtraction
b =  34
print(a - b)
# Out:
# 11

# %%
a = 45#multipcation
b =  34
print(a*b)
# Out:
# 1530

# %%
a = 45
b =  34
print(a % b)
# Out:
# 11

# %%
a = 45
b =  34
print(a**b)
# Out:
# 161892029831473198287006104499893845058977603912353515625

# %%
a = 45
b =  34
print(a//b)
# Out:
# 1

# %%
a  = "abu"
b = "ABU"
print(a is b)
# Out:
# False

# %%
#5/23/2026

# %%
a = ["abubkar","khan","azan","king","fozan"]
print(a)
print(type(a))
# Out:
# ['abubkar', 'khan', 'azan', 'king', 'fozan']
# <class 'list'>

# %%
a =  ["my age is",11]
print(a)
print(len(a))
# Out:
# ['my age is', 11]
# 2

# %%
a = list(("abubkar","khan"))
print(a)
print(type(a))
# Out:
# ['abubkar', 'khan']
# <class 'list'>

# %%
a = [11,22,33,44,55,66,77,88,99]
print(a[2:5])
# Out:
# [33, 44, 55]

# %%
a = [11,22,33,44,55]
print(a[1:3])
print(a[0:])
print(a[:4])
print(a[3:])
print(a[-4:-1])
print(a[3:1])
# Out:
# [22, 33]
# [11, 22, 33, 44, 55]
# [11, 22, 33, 44]
# [44, 55]
# [22, 33, 44]
# []

# %%
a = [11,22,33,44,55]
if 67 in a:
    print("ok")
else:
    print("on")
# Out:
# on

# %%
a = ["abubkar","khan"]
a[1]= "fozan"
print(a)
# Out:
# ['abubkar', 'fozan']

# %%
a = [11,33,44,55,77,99]
a.insert(2, "abu") 
print(a)
# Out:
# [11, 33, 'abu', 44, 55, 77, 99]

# %%
a = ["abubkar","azan","fozan"]
for i in range (len(a)):
    dl=a[i]
    print(del  a [dl])
# Out:
# abubkar
# azan
# fozan

# %%
a = ["abubkar","azan","fozan" , "ali " , "khan"]
for i in a[:]:
    print("deleted",a)
    
    print(a.remove(i))
print(a)
# Out:
# deleted ['abubkar', 'azan', 'fozan', 'ali ', 'khan']
# None
# deleted ['azan', 'fozan', 'ali ', 'khan']
# None
# deleted ['fozan', 'ali ', 'khan']
# None
# deleted ['ali ', 'khan']
# None
# deleted ['khan']
# None
# []

# %%
a = ["abubkar","azan","fozan" , "ali " , "khan"]
i = len(a) -1
while i  >=0:
    
    print(a[i])
    i=i-2
# Out:
# khan
# fozan
# abubkar

# %%
a = ["abubkar","azan","fozan" , "ali " , "khan"]
print(a.append("king"))
print(a)
# Out:
# None
# ['abubkar', 'azan', 'fozan', 'ali ', 'khan', 'king']

# %%
a = ["abubkar","azan","fozan" , "ali " , "khan"]
x=[]
for i in a[:]:
    a.append(i)
print(a)
# Out:
# ['abubkar', 'azan', 'fozan', 'ali ', 'khan', 'abubkar', 'azan', 'fozan', 'ali ', 'khan']

# %%
a = ["abubkar","azan","fozan" , "ali " , "khan"]
x=[v for v in a]
print(a)
# Out:
# ['abubkar', 'azan', 'fozan', 'ali ', 'khan']

# %%
ali = ["abubkar","azan","fozan" , "ali " , "khan"]
x=[i for i in ali if i == "khan"]
print(i)
# Out:
# khan

# %%
a = ["abubkar","azan","fozan" , "ali " , "khan"]
x=[i.upper()for i in a]
print(x)
# Out:
# ['ABUBKAR', 'AZAN', 'FOZAN', 'ALI ', 'KHAN']

# %%
a = ["abubkar","azan","fozan" , "ali " , "khan"]
for i in a:
    print(i.upper())
# Out:
# ABUBKAR
# AZAN
# FOZAN
# ALI
# KHAN

# %%
def a():
    print("my name is aubkar")
a()
# Out:
# my name is aubkar

# %%
def a(sname,name,csll):
    print(f"my name is {sname} my name is {name} my csll name {csll}")
a("azan","abubkar","6")
# Out:
# my name is azan my name is abubkar my csll name 6

# %%
def my(*kids):
    print("The youngest child is " + kids[2])
my("my","name","is")
# Out:
# The youngest child is is

# %%
##3
import re
a = "my name is abubkar"
x = re.findall("abubkar",a)
print(x)
# Out:
# ['abubkar']

# %%
import re
a = "my name is abubkar"
x = re.search("\s",a)
print("my sname is azan",x.start())
# Out:
# my sname is azan 2

# %%
import re
a = "my name is abubkar"
x = re.split("\s",a,)
print(x)
# Out:
# ['my', 'name', 'is', 'abubkar']

# %%
import re
a = "my name is abubkar"
x = re.sub("\s","9" ,a)
print(x)
# Out:
# my9name9is9abubkar

# %%
import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.span())
# Out:
# (12, 17)

# %%
import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.string)
# Out:
# The rain in Spain

# %%
a = ["abubkar","khan","azan","king","fozan"]
print(a)
print(type(a))
# Out:
# ['abubkar', 'khan', 'azan', 'king', 'fozan']
# <class 'list'>

# %%
a = ["abubkar","azan","fozan" , "ali " , "khan"]
for i in a[:]:
    print("deleted",a)
    
    print(a.remove(i))
print(a)
# Out:
# deleted ['abubkar', 'azan', 'fozan', 'ali ', 'khan']
# None
# deleted ['azan', 'fozan', 'ali ', 'khan']
# None
# deleted ['fozan', 'ali ', 'khan']
# None
# deleted ['ali ', 'khan']
# None
# deleted ['khan']
# None
# []

# %%
def a(sname,name,csll):
    print(f"my name is {sname} my name is {name} my csll name {csll}")
a("azan","abubkar","6")
# Out:
# my name is azan my name is abubkar my csll name 6
